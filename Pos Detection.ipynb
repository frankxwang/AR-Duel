# %%
from scipy import io

# %%
io.loadmat("/Users/frank/Downloads/FLIC/examples.mat")
# Out:
# /Users/frank/anaconda/lib/python3.6/site-packages/numpy/core/arrayprint.py:654: RuntimeWarning: invalid value encountered in greater_equal
#   max_str_len = max(len(str(maximum.reduce(data))),
# {'__globals__': [],
#  '__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sat Apr  6 19:54:17 2013',
#  '__version__': '1.0',
#  'examples': array([[ (array([[ 48],
#         [148],
#         [ 19],
#         [ 11],
#         [138],
#         [ 35],
#         [  9],
#         [ 85],
#         [ 40],
#         [ 57],
#         [ 61],
#         [ 21],
#         [ 59],
#         [  6],
#         [ 41],
#         [ 38],
#         [119],
#         [ 43],
#         [ 24],
#         [101],
#         [118],
#         [136],
#         [ 67]], dtype=uint16), array(['12-oclock-high-special-edition'],
#        dtype='<U30'), array([[ 327.87756348,  331.83673096,  367.46939087,  195.24490356,
#           175.44897461,  165.55102539,  284.32653809,           nan,
# ...
